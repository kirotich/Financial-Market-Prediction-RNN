# 1243   12/9/2016  780.00  789.43  779.02  789.29   1,821,900
# 1244  12/12/2016  785.04  791.25  784.35  789.27   2,104,100
# 1245  12/13/2016  793.90  804.38  793.34   796.1   2,145,200
# 1246  12/14/2016  797.40  804.00  794.01  797.07   1,704,200
# 1247  12/15/2016  797.34  803.00  792.92  797.85   1,626,500
# 1248  12/16/2016  800.40  800.86  790.29   790.8   2,443,800
# 1249  12/19/2016  790.22  797.66  786.27   794.2   1,232,100
# 1250  12/20/2016  796.76  798.65  793.27  796.42     951,000
# 1251  12/21/2016  795.84  796.68  787.10  794.56   1,211,300
# 1252  12/22/2016  792.36  793.32  788.58  791.26     972,200
# 1253  12/23/2016  790.90  792.74  787.28  789.91     623,400
# 1254  12/27/2016  790.68  797.86  787.66  791.55     789,100
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1,153,800
# 1256  12/29/2016  783.33  785.93  778.92  782.79     744,300
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 6 columns]

# %%
#Extract first column from the csv file -- opening stock price as a matrix not vector
training_set = training_set.iloc[:,1:2].values
training_set
# Out:
# array([[ 325.25],
#        [ 331.27],
#        [ 329.83],
#        ...,
#        [ 793.7 ],
#        [ 783.33],
#        [ 782.75]])

# %%
#Apply feature scaling - normalize from zero to one
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler() #default normalization is 0-1

# %%
#Fit to training set -- apply min and max of training set
training_set = sc.fit_transform(training_set)

# %%
#Visualize data
plt.figure()
plt.plot(training_set, color = 'black', label = 'Normalised training set')
plt.xlabel('Time period')
plt.ylabel('Stocks Value')
plt.show
plt.title('Normalised Training Set')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Cutting Time Series into Subsequences**

# %%
#Cutting Time Series into Sub Sequences

def window_transform_series(series,window_size):
    # containers for input/output pairs
    X = []
    y = []

    for i in range(window_size,len(series)):
        X.append(series[i-window_size: i])
        y.append(series[i])
        
    # reshape each to return I/O as NP arrays
    X = np.asarray(X)
    X.shape = (np.shape(X)[0:2])
    y = np.asarray(y)
    y.shape = (len(y),1)
    
    return X,y

# %%
#window the data using your windowing function
window_size = 4 #A week
X,y = window_transform_series(series = training_set,window_size = window_size)

# %%
X_train = X[0:] 

print(X[0:3])
print(y[1:3])
X_train.shape
# Out:
# [[ 0.08581368  0.09701243  0.09433366  0.09156187]
#  [ 0.09701243  0.09433366  0.09156187  0.07984225]
#  [ 0.09433366  0.09156187  0.07984225  0.0643277 ]]
# [[ 0.0643277]
#  [ 0.0585423]]
# (1254, 4)

# %%
y_train = y[0:] #till the last day training period
y_train.shape
# Out:
# (1254, 1)

# %%
#Reshape inputs to a 3D Array 
#samples, time steps, features

X_train = np.reshape(X_train, (X_train.shape[0],window_size,1))
X_train
# Out:
# array([[[ 0.08581368],
#         [ 0.09701243],
#         [ 0.09433366],
#         [ 0.09156187]],
#
#        [[ 0.09701243],
#         [ 0.09433366],
#         [ 0.09156187],
#         [ 0.07984225]],
#
#        [[ 0.09433366],
#         [ 0.09156187],
#         [ 0.07984225],
#         [ 0.0643277 ]],
#
#        ...,
#        [[ 0.96123223],
#         [ 0.95475854],
#         [ 0.95204256],
#         [ 0.95163331]],
#
#        [[ 0.95475854],
#         [ 0.95204256],
#         [ 0.95163331],
#         [ 0.95725128]],
#
#        [[ 0.95204256],
#         [ 0.95163331],
#         [ 0.95725128],
#         [ 0.93796041]]])

# %%
#Import Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
# Out:
# Using TensorFlow backend.

# %%
#Initialize RNN - Regression model - stock price is continous
regressor = Sequential() #a sequence of layers

# %%
#Add LSTM layer which takes as input the input layer 

regressor.add(LSTM(units = 4, activation = 'sigmoid', input_shape= (window_size,1)))

# %%
#Output layer - Dense Class
#Units - no of neurons in output layer. stock price

regressor.add(Dense(units = 1))

# %%
#Compile the RNN
regressor.compile(optimizer = 'RMSprop', loss ='mean_squared_error')

# %%
#Fit RNN to training set 
regressor.fit(X_train, y_train, batch_size = 32, epochs = 250)
# Out:
# Epoch 1/250
# 1254/1254 [==============================] - 0s - loss: 0.1282
# Epoch 2/250
# 1254/1254 [==============================] - 0s - loss: 0.0782
# Epoch 3/250
# 1254/1254 [==============================] - 0s - loss: 0.0617
# Epoch 4/250
# 1254/1254 [==============================] - 0s - loss: 0.0573
# Epoch 5/250
# 1254/1254 [==============================] - 0s - loss: 0.0532
# Epoch 6/250
# 1254/1254 [==============================] - 0s - loss: 0.0490
# Epoch 7/250
# 1254/1254 [==============================] - 0s - loss: 0.0448
# Epoch 8/250
# 1254/1254 [==============================] - 0s - loss: 0.0405
# Epoch 9/250
# 1254/1254 [==============================] - 0s - loss: 0.0361
# Epoch 10/250
# 1254/1254 [==============================] - 0s - loss: 0.0315
# Epoch 11/250
# 1254/1254 [==============================] - 0s - loss: 0.0268
# Epoch 12/250
# 1254/1254 [==============================] - 0s - loss: 0.0225
# Epoch 13/250
# 1254/1254 [==============================] - 0s - loss: 0.0184
# Epoch 14/250
# 1254/1254 [==============================] - 0s - loss: 0.0143
# Epoch 15/250
# 1254/1254 [==============================] - 0s - loss: 0.0104
# Epoch 16/250
# 1254/1254 [==============================] - 0s - loss: 0.0070
# Epoch 17/250
# 1254/1254 [==============================] - 0s - loss: 0.0043
# Epoch 18/250
# 1254/1254 [==============================] - 0s - loss: 0.0023
# Epoch 19/250
# 1254/1254 [==============================] - 0s - loss: 9.9980e-04
# Epoch 20/250
# 1254/1254 [==============================] - 0s - loss: 4.2062e-04
# Epoch 21/250
# 1254/1254 [==============================] - 0s - loss: 3.0508e-04
# Epoch 22/250
# 1254/1254 [==============================] - 0s - loss: 3.0276e-04
# Epoch 23/250
# 1254/1254 [==============================] - 0s - loss: 2.9904e-04
# Epoch 24/250
# 1254/1254 [==============================] - 0s - loss: 3.0378e-04
# Epoch 25/250
# 1254/1254 [==============================] - 0s - loss: 2.9984e-04
# Epoch 26/250
# 1254/1254 [==============================] - 0s - loss: 3.0248e-04
# Epoch 27/250
# 1254/1254 [==============================] - 0s - loss: 2.9501e-04
# Epoch 28/250
# 1254/1254 [==============================] - 0s - loss: 2.9419e-04
# Epoch 29/250
# 1254/1254 [==============================] - 0s - loss: 2.9781e-04
# Epoch 30/250
# 1254/1254 [==============================] - 0s - loss: 2.8761e-04
# Epoch 103/250
# 1254/1254 [==============================] - 0s - loss: 2.9224e-04
# Epoch 104/250
# 1254/1254 [==============================] - 0s - loss: 2.9261e-04
# Epoch 105/250
# 1254/1254 [==============================] - 0s - loss: 2.9048e-04
# Epoch 106/250
# 1254/1254 [==============================] - 0s - loss: 2.9499e-04
# Epoch 107/250
# 1254/1254 [==============================] - 0s - loss: 2.8744e-04
# Epoch 108/250
# 1254/1254 [==============================] - 0s - loss: 2.9397e-04
# Epoch 109/250
# 1254/1254 [==============================] - 0s - loss: 2.9216e-04
# Epoch 110/250
# 1254/1254 [==============================] - 0s - loss: 2.9268e-04
# Epoch 111/250
# 1254/1254 [==============================] - 0s - loss: 2.9554e-04
# Epoch 112/250
# 1254/1254 [==============================] - 0s - loss: 2.9050e-04
# Epoch 113/250
# 1254/1254 [==============================] - 0s - loss: 2.9027e-04
# Epoch 114/250
# 1254/1254 [==============================] - 0s - loss: 2.8405e-04
# Epoch 115/250
# 1254/1254 [==============================] - 0s - loss: 2.9489e-04
# Epoch 116/250
# 1254/1254 [==============================] - 0s - loss: 2.9045e-04
# Epoch 117/250
# 1254/1254 [==============================] - 0s - loss: 2.9220e-04
# Epoch 118/250
# 1254/1254 [==============================] - 0s - loss: 2.9245e-04
# Epoch 119/250
#  992/1254 [======================>.......] - ETA: 0s - loss: 2.6071e-04

# %%
#R
regressor.summary()

# %%
#Import stock price 2017 -- TEST
test_set = pd.read_csv('goog.csv')
test_set

# %%
stock_price = test_set.iloc[:,1:2].values
stock_price

# %%
inputs = stock_price

#Scale inputs
inputs = sc.fit_transform(inputs)
inputs

# %%
#Reshape input 
inputs_sub_x,inputs_y = window_transform_series(series = inputs,window_size = window_size)
inputs_sub_x
inputs_y

# %%
#Reshape to 3D Array
inputs_reshaped = np.reshape(inputs_sub_x,(inputs_sub_x.shape[0],window_size,1))

# %%
#Predict -- returns scaled output 
predicted_stock_price = regressor.predict(inputs_reshaped)

# %%
#Scale back
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price

# %%
#Visualizing predictions

plt.figure()
plt.plot(stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title("Google Stock Price Prediction")
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
#Predicted stock from 2012 to 2016
stock_price_from_train = pd.read_csv('Google_Stock_Price_Train.csv')

stock_price_from_train = stock_price_from_train.iloc[:,1:2].values
stock_price_from_train
stock_price_from_train = sc.fit_transform(stock_price_from_train)

# %%
#Getting the predicted stock
predicted_stock_price_from_train = regressor.predict(X_train)

#Unscale X_train
#predicted_stock_price_from_train = sc.inverse_transform(predicted_stock_price_from_train)

# %%
#Visualizing predictions
plt.figure()
plt.plot(stock_price_from_train, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price_from_train, color = 'blue', label = 'Predicted Google Stock Price')

# %%
plt.title("Google Stock Price Prediction")
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
#Evaluating RNN
import math # root of mean sqaured error
from sklearn.metrics import mean_squared_error
rmse = math.sqrt(mean_squared_error(stock_price,predicted_stock_price))
rmse

# %%
rmse/800
